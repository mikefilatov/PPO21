# %% [markdown]
# # Задача 1
#
# 1. В переменную `list_a` сохраните результат деления всех чисел на 13
# 2. В переменную `sinus_list` сохраните синусы значений списка super_list
# 3. В переменную `short` сохраните кубы всех элементов c 7 по 20 списка `super_list` (здесь и далее счиатем, что номер элемента соотвествует реально расположению элемента в списке)
# 4. В переменную `int_list` сохраните преобразованные в целые числа элементы списка `super_list`
# 5. В список `min_list` сохраните все значения списка `super_list`, перед этим отняв минимальное значение списка `super_list` (минимум можно найти с помощью функции `min`, например `min([1, 2, 3])` вернет `1`, аналогично можно найти максимум с помощью функции `max`)
# 6. (со звездочкой) Создайте список `try_hard`, который выглядит следующим образом: если число из списка меньше единицы, то оно выводится в список как есть, в противном случае в список выводится `True`. Использовать управляющую конструкцию `if ... else` нельзя.  (подсказка: вспомните булевы значения; посмотрите на решение предыдущего пункта)

# %%
super_list = [-40.63362616042127,
 -132.50191149049454,
 90.24294027202839,
 172.95057390739674,
 193.20222412139748,
 157.47976829541815,
 120.05987847791937,
 -24.57018719906499,
 1.0391852962091832,
 291.85315977764753,
 140.21057410142464,
 217.53000469578302,
 313.40863327876866,
 46.32031636563716,
 62.718475797180126,
 -57.41574255822579,
 143.99368426436757,
 64.5556959266672,
 24.48593912187033,
 261.3725298462334,
 179.01849204236817,
 276.0871871348981,
 29.31092297773806,
 -2.7399085058927852,
 111.61626627590118]

# Ваше решение здесь

# %% [markdown]
# # Задача 2
#
# Дана строка "Мама мыла раму". С помощью изученных нами методов строк, списков и циклов получите следующую строку: "РАМУ мыла МАМА"

# %%
# Ваше решение здесь

# %% [markdown]
# # Задача 3
#
# Напишите программу, которая на вход получает строку в нижнем регистре, а на выходе выдает строку, где у каждого третьего, начиная со второго, символа регистр изменен на верхний

# %%
# Ваше решение здесь

# %% [markdown]
# # Задача 4
#
# Даны два списка
#
# ```python
# artist = ["Pink Floyd", "Beatles", "The Police", "Led Zeppilin"]
#
# song  = ["Wish You Were Here", "Let It Be", "Every Breath You Take", "Whole Lotta Love"]
# ```
# Создайте список `summary`,  в котором будут храниться строки следующего вида: <исполнитель> - <песня>
#
# Пример первой строки: `"Pink Floyd - Wish You Were Here"`

# %%
# Ваше решение здесь

# %% [markdown]
# # Задача 5
#
# дан список
#
# `numbers = [34, 88, 23, 72, 67, 79,  2, 20, 12, 94, 48, 22, 44,  1, 93, 89, 74, 13, 38, 77]`
#
# В список new сохраните остатки от деления каждого числа на 2. Должен получиться список из ноликов и единичек. Посчитайте долю нечетных чисел в списке `numbers`

# %%
# Ваше решение здесь

# %% [markdown]
# # Задача 6
#
# Дана строка. Получите новую строку, вставив между каждыми двумя символами исходной строки символ `*`. Выведите полученную строку.

# %%
# Ваше решение здесь

# %% [markdown]
# # Задача 7
#
# Дана строка. Извлеките из нее все числа. Под числом понимается непрерывная последовательность цифр.
#
# __Пример__
#
# __Входные данные__
#
# 8 cv4f45 5x 56 9p0
#
# __Выходные данные__
#
# 8 4 45 5 56 9 0
