# %% [markdown]
# ## Задача 1
#
# Выведите все точные квадраты натуральных чисел, не превосходящие данного числа N.
#
# __Входные данные__
#
# Задано единственное целое число N
#
# __Выходные данные__
#
# Необходимо вывести  все точные квадраты натуральных чисел, не превосходящие данного числа N.

# %%
# Ваш код здесь

# %% [markdown]
# ## Задача 2.1
#
# Выведите наименьший делитель числа N отличный от единицы
#
# __Входные данные__
#
# Задано единственное целое число N
#
# __Выходные данные__
#
# Наименьший делитель

# %%
# Ваш код здесь

# %% [markdown]
# ## Задача 2.2
#
# Выведите наименьший делитель числа N отличный от единицы, если наименьший делитель равен самому числу, то программа должна вывести "Это простое число"
#
# __Пример__
#
# __Входные данные__
#
# 17
#
# __Выходные данные__
#
# Это простое число

# %%
# Ваш код здесь

# %% [markdown]
# ## Задача 3
#
# Напишите программу, которая получает на вход получает число и вычитает из него 7 до тех пор, пока результат не будет делиться на 123 без остатка, затем программа должна вывести получившееся число на экран
#
# __Пример__
#
# __Входные данные__
#
# 100
#
# __Выходные данные__
#
# -369

# %%
# Ваш код здесь

# %% [markdown]
# ## Задача 4
#
# Напишите программу, которая для всех четных чисел от m до k выводит количество кратных им чисел, не превышающих число n.
#
# __Входные данные__
#
# 2
#
# 12
#
# 126
#
# __Выходные данные__
#
# 2 63
#
# 4 31
#
# 6 21
#
# 8 15
#
# 10 12
#
# 12 10

# %%
# Ваш код здесь

# %% [markdown]
# ## Задача 5
#
# Напишите программу, которая "переворачивает" число.
#
# __Пример__
#
# __Входные данные__
#
# 12345
#
# __Выходные данные__
#
# 54321

# %%
# Ваш код здесь
